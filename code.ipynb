# %%
# !pip install torch torchvision torchaudio
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 3.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/159.7 MB ? eta -:--:--
#    ---------------------------------------- 0.1/159.7 MB 6.8 MB/s eta 0:00:24
#    ---------------------------------------- 0.2/159.7 MB 3.1 MB/s eta 0:00:53
#    ---------------------------------------- 0.4/159.7 MB 3.9 MB/s eta 0:00:42
#    ---------------------------------------- 0.6/159.7 MB 3.6 MB/s eta 0:00:45
#    ---------------------------------------- 0.8/159.7 MB 3.9 MB/s eta 0:00:41
#    ---------------------------------------- 0.9/159.7 MB 3.8 MB/s eta 0:00:42
#    ---------------------------------------- 1.1/159.7 MB 3.6 MB/s eta 0:00:45
#    ---------------------------------------- 1.4/159.7 MB 3.8 MB/s eta 0:00:43
#    ---------------------------------------- 1.4/159.7 MB 3.4 MB/s eta 0:00:47
# ...

# %%
import torch
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt

# Load YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# Set confidence threshold
model.conf = 0.3

# Function to perform object detection on an image
def detect_objects(image_url):
    # Extract image ID from URL
    image_id = image_url.split('/')[-2]

    # Construct direct image URL
    direct_url = f"https://drive.google.com/uc?id={image_id}"

    # Load the image
    response = requests.get(direct_url)
    img = Image.open(BytesIO(response.content))

    # Perform object detection
    results = model(img)

    # Display the results with smaller size
    plt.figure(figsize=(4, 2))
    results.show()

    # Return the results
    return results

# URL of the image
image_url = "https://drive.google.com/file/d/1ha0I6Xz9F-_zbI4snOCX8FJ48CgnzmQ8/view?usp=sharing"

# Perform object detection on the image
detect_objects(image_url)
# Out:
# Using cache found in C:\Users\alamp/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-5-25 Python-3.12.2 torch-2.3.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# <PIL.Image.Image image mode=RGB size=702x1600>
# YOLOv5 <class 'models.common.Detections'> instance
# image 1/1: 1600x702 2 persons, 1 dog, 5 chairs, 2 dining tables
# Speed: 12.5ms pre-process, 122.2ms inference, 0.0ms NMS per image at shape (1, 3, 640, 288)
